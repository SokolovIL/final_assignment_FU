# %% [markdown]
# # Шаг 16. Создание производных признаков

# %% [markdown]
# Создание производных признаков не требуется. Все необходимые на данном этапе признаки (era, decade, years_since_release, period_duration и т.д.) созданы ранее.
