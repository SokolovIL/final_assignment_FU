# %% [markdown]
# # Шаг 7. Первичный просмотр структуры таблиц

# %%
# Предполагается, что на предыдущем шаге мы уже загрузили данные:
# df_consolidated = pd.read_csv('df_consolidated.csv')

print("=== Первые 5 строк консолидированной таблицы ===")
display(df_consolidated.head())

print("\n=== Последние 5 строк консолидированной таблицы ===")
display(df_consolidated.tail())

print("\n=== Общая информация о таблице ===")
print(f"Всего строк: {len(df_consolidated)}")
print(f"Всего столбцов: {len(df_consolidated.columns)}")
print("Список столбцов:", df_consolidated.columns.tolist())
# Out:
# === Первые 5 строк консолидированной таблицы ===
#    ID                                Header  Years_from  Years_to  \
# 0   1      Accurate British Infantry (7200)        1768      1796
# 1   2      Accurate American Militia (7201)        1775      1780
# 2   3        Accurate Union Infantry (7202)        1861      1865
# 3   4  Accurate Union Artillery Team (7204)        1861      1865
# 4   5        Accurate Union Pioneers (7205)        1861      1865
#
#    Release_Year  Aggregate_Rating  Num_Figures Manufacturer  Period_Duration  \
# 0           NaN              47.0         50.0     Accurate               28
# 1           NaN              48.0         50.0     Accurate                5
# 2        1991.0              48.0         50.0     Accurate                4
# 3           NaN              34.0         18.0     Accurate                4
# 4           NaN              44.0         31.0     Accurate                4
#
# ...

# %% [markdown]
# ## Результат шага
# Первичный просмотр структуры таблицы выполнен. Визуально подтверждено, что:
# - Данные прочитаны корректно.
# - Разделители отработали верно.
# - Структура соответствует ожидаемой.
